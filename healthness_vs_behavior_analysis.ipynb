# %% [markdown]
# Null Hypotheses:
#
# Having a higher healthness score(healthier behaviour) has no affect on healehness in terms of rate of decreases.

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

from helpers import lin_reg
from helpers import box_plot

# File to Load (Remember to Change These)
csv_path = Path("datasets/CVD_cleaned.csv")

data_df = pd.read_csv(csv_path)

# %%
data_df.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex  ... Height_(cm)  \
# 0           No         No       No       Yes  Female  ...         150
# 1           No         No      Yes        No  Female  ...         165
# 2           No         No      Yes        No  Female  ...         163
# 3           No         No      Yes        No    Male  ...         180
# 4           No         No       No        No    Male  ...         191
#
#    Weight_(kg)    BMI  Smoking_History Alcohol_Consumption  Fruit_Consumption  \
# ...

# %%
help(lin_reg)
# Out:
# Help on function lin_reg in module helpers:
#
# lin_reg(plt, linregress, df, xcol, ycol, xlabel, ylabel)

# %%
lin_reg(plt, linregress, data_df, 'Healthness_Score','Behaviour Score', 'Healthness Score', 'Behaviour Score')
# Out:
# The r-value is: 0.07732468127570527
